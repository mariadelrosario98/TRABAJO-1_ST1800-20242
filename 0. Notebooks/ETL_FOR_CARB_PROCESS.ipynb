# %%
# !pip install boto3

import boto3
import pandas as pd

BUCKET_NAME = "rawtrabajo1"
KEY = "raw/FOR_CARB/for_carb.csv"

s3 = boto3.resource(
    's3',
    aws_access_key_id= "ASIARVBGHGL4DZD45F5G",
    aws_secret_access_key= "Xm6i+U/7nenuhSvHzLE4PFxffskfcG5fhdXmi8gP",
    aws_session_token="..."
)

s3.Bucket(BUCKET_NAME).download_file(KEY, 'for_carb.csv')

df = pd.read_csv('for_carb.csv')

df.to_csv('for_carb.txt', index=False, sep='\t')

#Enviamos los datos a S3
s3.meta.client.upload_file('for_carb.txt', Bucket='trustedtrabajo1', Key='trusted/for_carb.txt')

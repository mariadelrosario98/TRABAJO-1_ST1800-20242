# %%
# !pip install boto3

import boto3
import pandas as pd

BUCKET_NAME = "rawtrabajo1"
KEY = "raw/TEMP_CHANGE/temp_change.csv"

s3 = boto3.resource(
    's3',
    aws_access_key_id= "ASIARVBGHGL4DZD45F5G",
    aws_secret_access_key= "Xm6i+U/7nenuhSvHzLE4PFxffskfcG5fhdXmi8gP",
    aws_session_token="..."
)

s3.Bucket(BUCKET_NAME).download_file(KEY, 'temp_change.csv')

df = pd.read_csv('temp_change.csv')

df.to_csv('temp_change.txt', index=False, sep='\t')

#Enviamos los datos a S3
s3.meta.client.upload_file('temp_change.txt', Bucket='trustedtrabajo1', Key='trusted/temp_change.txt')
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 139.2/139.2 kB 1.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.5/12.5 MB 51.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 82.7/82.7 kB 3.3 MB/s eta 0:00:00
# ...

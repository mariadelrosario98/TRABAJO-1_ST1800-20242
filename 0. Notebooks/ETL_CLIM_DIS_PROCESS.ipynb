# %%
# !pip install boto3

# %%
import boto3
import pandas as pd

# %%
BUCKET_NAME = "rawtrabajo1"
KEY = "raw/CLIM_DIS/clim_dis.csv"

# %%
s3 = boto3.resource(
    's3',
    aws_access_key_id= "ASIARVBGHGL4DZD45F5G",
    aws_secret_access_key= "Xm6i+U/7nenuhSvHzLE4PFxffskfcG5fhdXmi8gP",
    aws_session_token="..."
)

# %%
s3.Bucket(BUCKET_NAME).download_file(KEY, 'clim_dis.csv')

# %%
df = pd.read_csv('clim_dis.csv')

df.to_csv('clim_dis.txt', index=False, sep='\t')

# %%
#Enviamos los datos a S3
s3.meta.client.upload_file('clim_dis.txt', Bucket='trustedtrabajo1', Key='trusted/clim_dis.txt')
